# %%
import os
import cv2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings

# %%
class_list = os.listdir('data/')
class_list.remove('.DS_Store')
class_list
# Out:
# ['dogs', 'cats', 'bike', 'horses', 'cars', 'human']

# %%
class_dict = dict(zip(class_list, list(range(0,len(class_list)))))
class_dict
# Out:
# {'dogs': 0, 'cats': 1, 'bike': 2, 'horses': 3, 'cars': 4, 'human': 5}

# %%
image_list = []


for cls in class_list:
    images = os.listdir('data/' + cls)
    for i in images:
        img = cv2.imread('data/' + cls + '/' + i)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img,(128,128))
        image_list.append(img)
image_array = np.array(image_list)
image_array = image_array.astype('float32')

# %%
print(type(image_array))
print(image_array.dtype)
print(image_array.shape)
# Out:
# <class 'numpy.ndarray'>
# float32
# (1593, 128, 128)

# %%
for i in range (25,28):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    plt.show()

# %%
image_array = np.expand_dims(image_array, axis=3) 
image_array.shape
# Out:
# (1593, 128, 128, 1)

# %%
def get_labels():
    labels = np.ones((image_array.shape[0]), dtype='int')
    count=0
    for cls in class_list:
        images = os.listdir('data/' + cls)
        labels[count:(len(images)+count)] = class_dict[cls]
        count += len(images)
    return labels

labels = get_labels()

# %%
from keras.utils import np_utils

Y = np_utils.to_categorical(labels, len(class_list))

# %%
length_counts = []

for i in Y:
    if len(i) not in length_counts:
        length_counts.append(len(i))
length_counts
# Out:
# [6]

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

x, y = shuffle(image_array, Y, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=42)

# %%
print("X_train shape = {}".format(X_train.shape))
print("X_test shape = {}".format(X_test.shape))
# Out:
# X_train shape = (1354, 128, 128, 1)
# X_test shape = (239, 128, 128, 1)

# %%
image = X_train[1004]
plt.imshow(image)
plt.show()

# %%
input_shape=image_array[0].shape
# input_shape = image_array.shape[0]
input_shape
# Out:
# (128, 128, 1)

# %%
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers.core import Dense, Dropout, Activation, Flatten

cnn_model = Sequential([
    Convolution2D(32,3,3,activation='relu',input_shape = input_shape),
    Convolution2D(32,3,3,activation='relu'),
    MaxPooling2D(pool_size=(2,2)) ,
    Dropout(0.5),
    Flatten(), 
    Dense(128,activation='relu'),
    Dropout(0.5),
    Dense(len(class_list),activation = 'softmax')
]);
# Out:
# Metal device set to: Apple M1 Pro
# 2022-05-13 15:28:42.997445: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-13 15:28:42.997575: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
cnn_model.compile(loss='categorical_crossentropy', optimizer='adadelta',metrics=["accuracy"])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 42, 42, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 7, 7, 32)         0
#  )
#
#  dropout (Dropout)           (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 128)               200832
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 211,174
# Trainable params: 211,174
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_channel=1
num_epoch=100

# %%
hist = cnn_model.fit(X_train, y_train, batch_size=16, epochs=num_epoch, verbose=1, validation_data=(X_test, y_test))
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['accuracy']
val_acc=hist.history['val_accuracy']
xc=range(num_epoch)
# Out:
# Epoch 1/100
# 2022-05-13 15:28:43.230902: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-13 15:28:43.415831: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 85/85 [==============================] - 1s 12ms/step - loss: 42.7217 - accuracy: 0.1529 - val_loss: 19.4239 - val_accuracy: 0.1506
# Epoch 2/100
#  3/85 [>.............................] - ETA: 2s - loss: 31.9643 - accuracy: 0.2500
# 2022-05-13 15:28:44.507968: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#
# Epoch 23/100
# 85/85 [==============================] - 1s 10ms/step - loss: 17.3598 - accuracy: 0.1913 - val_loss: 10.3330 - val_accuracy: 0.2008
# Epoch 24/100
# 85/85 [==============================] - 1s 10ms/step - loss: 16.9341 - accuracy: 0.2038 - val_loss: 10.2679 - val_accuracy: 0.1925
# Epoch 25/100
# 85/85 [==============================] - 1s 10ms/step - loss: 16.3239 - accuracy: 0.1972 - val_loss: 10.1566 - val_accuracy: 0.1925
# Epoch 26/100
# 85/85 [==============================] - 1s 10ms/step - loss: 15.6898 - accuracy: 0.1883 - val_loss: 10.0319 - val_accuracy: 0.1925
# Epoch 27/100
# 85/85 [==============================] - 1s 10ms/step - loss: 15.8818 - accuracy: 0.1787 - val_loss: 9.9708 - val_accuracy: 0.1883
# Epoch 28/100
# 85/85 [==============================] - 1s 9ms/step - loss: 15.7442 - accuracy: 0.1994 - val_loss: 9.8812 - val_accuracy: 0.1883
# Epoch 29/100
# 85/85 [==============================] - 1s 9ms/step - loss: 14.5063 - accuracy: 0.2208 - val_loss: 9.8261 - val_accuracy: 0.1925
# Epoch 30/100
# 85/85 [==============================] - 1s 9ms/step - loss: 14.8001 - accuracy: 0.1979 - val_loss: 9.7368 - val_accuracy: 0.1925
# Epoch 31/100
# 85/85 [==============================] - 1s 16ms/step - loss: 14.2975 - accuracy: 0.2090 - val_loss: 9.6071 - val_accuracy: 0.1883
# Epoch 32/100
# 85/85 [==============================] - 1s 10ms/step - loss: 13.8823 - accuracy: 0.2371 - val_loss: 9.4672 - val_accuracy: 0.1925
# Epoch 33/100
# 85/85 [==============================] - 1s 10ms/step - loss: 14.0533 - accuracy: 0.2016 - val_loss: 9.4674 - val_accuracy: 0.1967
# Epoch 34/100
# 85/85 [==============================] - 1s 10ms/step - loss: 13.1167 - accuracy: 0.2090 - val_loss: 9.3396 - val_accuracy: 0.1967
# Epoch 35/100
# 85/85 [==============================] - 1s 11ms/step - loss: 13.2741 - accuracy: 0.2038 - val_loss: 9.2101 - val_accuracy: 0.1967
# Epoch 36/100
# 85/85 [==============================] - 1s 10ms/step - loss: 13.7441 - accuracy: 0.1935 - val_loss: 9.1006 - val_accuracy: 0.1967
# Epoch 37/100
# 85/85 [==============================] - 1s 10ms/step - loss: 13.3686 - accuracy: 0.2009 - val_loss: 9.0393 - val_accuracy: 0.1967
# Epoch 38/100
# 85/85 [==============================] - 1s 11ms/step - loss: 13.1189 - accuracy: 0.2038 - val_loss: 8.9000 - val_accuracy: 0.1967
# Epoch 39/100
# 85/85 [==============================] - 1s 10ms/step - loss: 12.7310 - accuracy: 0.2075 - val_loss: 8.8378 - val_accuracy: 0.2008
# Epoch 40/100
# 85/85 [==============================] - 1s 10ms/step - loss: 12.8246 - accuracy: 0.2179 - val_loss: 8.6782 - val_accuracy: 0.2008
# Epoch 41/100
# 85/85 [==============================] - 1s 12ms/step - loss: 12.4021 - accuracy: 0.2075 - val_loss: 8.5559 - val_accuracy: 0.2008
# Epoch 42/100
# 85/85 [==============================] - 1s 10ms/step - loss: 12.0284 - accuracy: 0.1920 - val_loss: 8.5084 - val_accuracy: 0.2008
# Epoch 43/100
# 85/85 [==============================] - 1s 10ms/step - loss: 12.4440 - accuracy: 0.1972 - val_loss: 8.4286 - val_accuracy: 0.2008
# 85/85 [==============================] - 1s 9ms/step - loss: 9.3206 - accuracy: 0.2171 - val_loss: 6.6802 - val_accuracy: 0.2134
# Epoch 65/100
# 85/85 [==============================] - 1s 9ms/step - loss: 9.0599 - accuracy: 0.2194 - val_loss: 6.5945 - val_accuracy: 0.2134
# Epoch 66/100
# 85/85 [==============================] - 1s 9ms/step - loss: 9.4362 - accuracy: 0.2171 - val_loss: 6.5786 - val_accuracy: 0.2134
# Epoch 67/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.9168 - accuracy: 0.2194 - val_loss: 6.4842 - val_accuracy: 0.2092
# Epoch 68/100
# 85/85 [==============================] - 1s 10ms/step - loss: 9.1573 - accuracy: 0.1972 - val_loss: 6.4034 - val_accuracy: 0.2092
# Epoch 69/100
# 85/85 [==============================] - 1s 9ms/step - loss: 9.0175 - accuracy: 0.2001 - val_loss: 6.3226 - val_accuracy: 0.2134
# Epoch 70/100
# 85/85 [==============================] - 1s 9ms/step - loss: 9.0691 - accuracy: 0.2134 - val_loss: 6.2855 - val_accuracy: 0.2134
# Epoch 71/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.7629 - accuracy: 0.2061 - val_loss: 6.2538 - val_accuracy: 0.2134
# Epoch 72/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.9067 - accuracy: 0.2112 - val_loss: 6.1975 - val_accuracy: 0.2134
# Epoch 73/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.9397 - accuracy: 0.2112 - val_loss: 6.1564 - val_accuracy: 0.2092
# Epoch 74/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.5755 - accuracy: 0.2171 - val_loss: 6.1234 - val_accuracy: 0.2008
# Epoch 75/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.8827 - accuracy: 0.2046 - val_loss: 6.0956 - val_accuracy: 0.2050
# Epoch 76/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.5047 - accuracy: 0.2120 - val_loss: 6.0406 - val_accuracy: 0.2176
# Epoch 77/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.5255 - accuracy: 0.1928 - val_loss: 6.0057 - val_accuracy: 0.2176
# Epoch 78/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.3569 - accuracy: 0.2068 - val_loss: 5.9157 - val_accuracy: 0.2176
# Epoch 79/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.0525 - accuracy: 0.2201 - val_loss: 5.8940 - val_accuracy: 0.2176
# Epoch 80/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.4250 - accuracy: 0.1883 - val_loss: 5.8453 - val_accuracy: 0.2218
# Epoch 81/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.3197 - accuracy: 0.2090 - val_loss: 5.7910 - val_accuracy: 0.2218
# Epoch 82/100
# 85/85 [==============================] - 1s 9ms/step - loss: 8.2555 - accuracy: 0.2120 - val_loss: 5.7081 - val_accuracy: 0.2218
# Epoch 83/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.8013 - accuracy: 0.2120 - val_loss: 5.6724 - val_accuracy: 0.2176
# Epoch 84/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.9456 - accuracy: 0.2223 - val_loss: 5.6235 - val_accuracy: 0.2218
# Epoch 85/100
# 85/85 [==============================] - 1s 10ms/step - loss: 8.2248 - accuracy: 0.1942 - val_loss: 5.5563 - val_accuracy: 0.2218
# Epoch 86/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.7551 - accuracy: 0.2090 - val_loss: 5.5050 - val_accuracy: 0.2218
# Epoch 87/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.9324 - accuracy: 0.2334 - val_loss: 5.5078 - val_accuracy: 0.2218
# Epoch 88/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.7730 - accuracy: 0.2120 - val_loss: 5.4640 - val_accuracy: 0.2218
# Epoch 89/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.3372 - accuracy: 0.2341 - val_loss: 5.4801 - val_accuracy: 0.2218
# Epoch 90/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.4474 - accuracy: 0.2334 - val_loss: 5.4185 - val_accuracy: 0.2218
# Epoch 91/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.5151 - accuracy: 0.2149 - val_loss: 5.4102 - val_accuracy: 0.2218
# Epoch 92/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.5063 - accuracy: 0.1876 - val_loss: 5.3605 - val_accuracy: 0.2218
# Epoch 93/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.4864 - accuracy: 0.2186 - val_loss: 5.3393 - val_accuracy: 0.2218
# Epoch 94/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.5636 - accuracy: 0.2179 - val_loss: 5.3025 - val_accuracy: 0.2218
# Epoch 95/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.0691 - accuracy: 0.2134 - val_loss: 5.2160 - val_accuracy: 0.2218
# Epoch 96/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.1224 - accuracy: 0.2157 - val_loss: 5.1535 - val_accuracy: 0.2259
# Epoch 97/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.4070 - accuracy: 0.2127 - val_loss: 5.1270 - val_accuracy: 0.2218
# Epoch 98/100
# 85/85 [==============================] - 1s 10ms/step - loss: 7.2665 - accuracy: 0.2216 - val_loss: 5.0992 - val_accuracy: 0.2259
# Epoch 99/100
# 85/85 [==============================] - 1s 9ms/step - loss: 7.2973 - accuracy: 0.2127 - val_loss: 5.0628 - val_accuracy: 0.2259
# Epoch 100/100
# 85/85 [==============================] - 1s 10ms/step - loss: 6.9190 - accuracy: 0.2053 - val_loss: 5.0421 - val_accuracy: 0.2218

# %%
plt.figure(1,figsize=(10,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Train Loss vs Validation Loss')
plt.grid(True)
plt.legend(['Train Loss','Validation Loss'])
plt.style.use(['classic'])

# %%
plt.figure(2,figsize=(10,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Train Accuracy vs Validation Accuracy')
plt.grid(True)
plt.legend(['Train Accuracy','Validation Accuracy'],loc=4)
plt.style.use(['classic'])

# %%
score = cnn_model.evaluate(X_test, y_test, verbose=0)
print('Test Loss:', score[0])
print('Test Accuracy:', score[1])
# Out:
# Test Loss: 5.042057037353516
# Test Accuracy: 0.22175732254981995
