# %%
import os
import cv2
import numpy as np
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings

# %%
def get_img_list(folder):
    folder = folder + '/'
    class_list = os.listdir(folder)
    class_list.remove('.DS_Store')
    class_dict = dict(zip(class_list, list(range(0,len(class_list)))))
    image_list = []
    for cls in class_list:
        images = os.listdir('data/' + cls)
    for i in images:
        img = cv2.imread('data/' + cls + '/' + i)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img,(128,128))
        image_list.append(img)
    image_array = np.array(image_list)
    image_array = image_array.astype('float32')
    image_array /= 255
    return class_list, class_dict, image_array
    
class_list, class_dict, image_array = get_img_list('data')

# %%
for i in range (0,3):
    plt.imshow(image_array[i]) 
    plt.show()

# %%
# image_array = np.expand_dims(image_array, axis=3) 
image_array.shape
# Out:
# (202, 128, 128)

# %%
def get_labels():
    labels = np.ones((image_array.shape[0]), dtype='int')
    count=0
    for cls in class_list:
        images = os.listdir('data/' + cls)
        labels[count:(len(images)+count)] = class_dict[cls]
        count += len(images)
#         print(len(images))
#         print(count)
    return labels

labels = get_labels()

# %%
print(class_dict)

for i in range (200,202):
    display(plt.imshow(image_array[i]))
# Out:
# {'dogs': 0, 'cats': 1, 'bike': 2, 'flowers': 3, 'horses': 4, 'cars': 5, 'human': 6}

# %%
# Dog0 0-202

for i in range (200,202):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])
    plt.show()

# Cat1 202-404

for i in range (402,404):
    plt.imshow(image_array[i], cmap=plt.cm.binary)
    print(class_list[labels[i]])
    plt.show()

# Bike2 404-769

for i in range (767,769):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])
    plt.show()

# Flower3 769-976

for i in range (974,976):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])
    plt.show()

# Horse4 976-1181

for i in range (1179,1181):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])
    plt.show()

# Car5 1181-1601

for i in range (1599,1601):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])   
    plt.show()

# Human6 1601-1803

for i in range (1801,1803):
    plt.imshow(image_array[i], cmap=plt.cm.binary) 
    print(class_list[labels[i]])
    plt.show()
# Out:
# dogs
# dogs
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [33], in <cell line: 10>()
#       8 # Cat1 202-404
#      10 for i in range (402,404):
# ---> 11     plt.imshow(image_array[i], cmap=plt.cm.binary)
#      12     print(class_list[labels[i]])
#      13     plt.show()
#
# IndexError: index 402 is out of bounds for axis 0 with size 202

# %%
from keras.utils import np_utils

y = np_utils.to_categorical(labels, len(class_list))

length_counts = []

for i in y:
    if len(i) not in length_counts:
        length_counts.append(len(i))
length_counts
# Out:
# [7]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(image_array, y, test_size=0.15, random_state=42, shuffle=True)

# %%
import random
for i in range(0,5):
    n = random.randint(1,len(X_train))
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    class_index = int(np.flatnonzero(y_train[i]))
    print(class_list[class_index])
    plt.show()
# Out:
# cats
# bike
# cats
# bike
# cars

# %%
# Flatten

# X_train = X_train.reshape(len(X_train), 128**2).astype('float32')
# X_test = X_test.reshape(len(X_test), 128**2).astype('float32')

print("X_train shape = {}".format(X_train.shape))
print("X_test shape = {}".format(X_test.shape))
# Out:
# X_train shape = (1532, 128, 128)
# X_test shape = (271, 128, 128)

# %%
image_array.shape
# Out:
# (1803, 128, 128)

# %%
input_shape=image_array[0].shape
# input_shape = image_array.shape[0]

# input_shape = np.expand_dims(input_shape, axis=0)
input_shape
# Out:
# (128, 128)

# %%
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Dense, Dropout, Activation, Flatten

from tensorflow.keras.layers import Conv2D, Conv1D

cnn_model = Sequential([
    Conv2D(32,1,1,padding='same',activation='relu',input_shape = (128, 128, 1)),
    Conv2D(32,1,1,activation='LeakyReLU'),
    MaxPooling2D(pool_size=(2,2)) ,
    Dropout(0.5),
    Flatten(), 
    Dense(128,activation='relu'),
    Dropout(0.5),
    Dense(len(class_list), activation = 'softmax')
])
# Out:
# Metal device set to: Apple M1 Pro
# 2022-05-16 18:08:09.319899: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-16 18:08:09.320028: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
cnn_model.compile(loss='categorical_crossentropy', optimizer='adadelta',metrics=['acc'])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      64
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      1056
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 16,779,367
# Trainable params: 16,779,367
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_channel=1
num_epoch=200

# %%
hist = cnn_model.fit(X_train, y_train, batch_size=32, epochs=num_epoch, verbose=1, validation_data=(X_test, y_test))
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']
xc=range(num_epoch)
# Out:
# Epoch 1/200
# 2022-05-16 18:08:09.473413: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#  1/48 [..............................] - ETA: 18s - loss: 1.8997 - acc: 0.2812
# 2022-05-16 18:08:09.677435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - ETA: 0s - loss: 1.9280 - acc: 0.1886
# 2022-05-16 18:08:13.906151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 5s 97ms/step - loss: 1.9280 - acc: 0.1886 - val_loss: 1.8979 - val_acc: 0.2325
# Epoch 2/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.9001 - acc: 0.2454 - val_loss: 1.8837 - val_acc: 0.2325
# Epoch 3/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8870 - acc: 0.2474 - val_loss: 1.8773 - val_acc: 0.2325
# Epoch 4/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8756 - acc: 0.2369 - val_loss: 1.8712 - val_acc: 0.2362
# Epoch 5/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.8707 - acc: 0.2500 - val_loss: 1.8660 - val_acc: 0.2362
# Epoch 6/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8612 - acc: 0.2441 - val_loss: 1.8598 - val_acc: 0.2362
# Epoch 7/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8558 - acc: 0.2709 - val_loss: 1.8547 - val_acc: 0.2399
# Epoch 8/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8471 - acc: 0.2611 - val_loss: 1.8492 - val_acc: 0.2399
# Epoch 9/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8398 - acc: 0.2709 - val_loss: 1.8450 - val_acc: 0.2435
# Epoch 10/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8395 - acc: 0.2663 - val_loss: 1.8384 - val_acc: 0.2472
# Epoch 11/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8324 - acc: 0.2781 - val_loss: 1.8333 - val_acc: 0.2509
# Epoch 12/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8238 - acc: 0.2872 - val_loss: 1.8261 - val_acc: 0.2620
# Epoch 13/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8161 - acc: 0.2866 - val_loss: 1.8200 - val_acc: 0.2731
# Epoch 14/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8175 - acc: 0.3009 - val_loss: 1.8179 - val_acc: 0.2804
# Epoch 15/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8045 - acc: 0.3029 - val_loss: 1.8120 - val_acc: 0.2878
# Epoch 16/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.8041 - acc: 0.2983 - val_loss: 1.8069 - val_acc: 0.2804
# Epoch 17/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7899 - acc: 0.3218 - val_loss: 1.8010 - val_acc: 0.2878
# Epoch 18/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7865 - acc: 0.3114 - val_loss: 1.7976 - val_acc: 0.2915
# Epoch 19/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7864 - acc: 0.3087 - val_loss: 1.7926 - val_acc: 0.2952
# Epoch 20/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7719 - acc: 0.3244 - val_loss: 1.7864 - val_acc: 0.3026
# Epoch 21/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7705 - acc: 0.3166 - val_loss: 1.7824 - val_acc: 0.3026
# Epoch 22/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7649 - acc: 0.3198 - val_loss: 1.7784 - val_acc: 0.3063
# Epoch 23/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7601 - acc: 0.3238 - val_loss: 1.7761 - val_acc: 0.3063
# Epoch 24/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7583 - acc: 0.3309 - val_loss: 1.7713 - val_acc: 0.3137
# Epoch 25/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7529 - acc: 0.3394 - val_loss: 1.7678 - val_acc: 0.3137
# Epoch 26/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7470 - acc: 0.3277 - val_loss: 1.7673 - val_acc: 0.3395
# Epoch 27/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7458 - acc: 0.3466 - val_loss: 1.7608 - val_acc: 0.3210
# Epoch 28/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7386 - acc: 0.3446 - val_loss: 1.7568 - val_acc: 0.3173
# Epoch 29/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7310 - acc: 0.3414 - val_loss: 1.7549 - val_acc: 0.3173
# Epoch 30/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7343 - acc: 0.3505 - val_loss: 1.7492 - val_acc: 0.3173
# Epoch 31/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7297 - acc: 0.3564 - val_loss: 1.7464 - val_acc: 0.3284
# Epoch 32/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7208 - acc: 0.3473 - val_loss: 1.7454 - val_acc: 0.3358
# Epoch 33/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7164 - acc: 0.3662 - val_loss: 1.7404 - val_acc: 0.3542
# Epoch 34/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7111 - acc: 0.3681 - val_loss: 1.7376 - val_acc: 0.3284
# Epoch 35/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.7084 - acc: 0.3662 - val_loss: 1.7358 - val_acc: 0.3506
# Epoch 36/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7052 - acc: 0.3708 - val_loss: 1.7311 - val_acc: 0.3542
# Epoch 37/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.7032 - acc: 0.3681 - val_loss: 1.7273 - val_acc: 0.3579
# Epoch 38/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6969 - acc: 0.3734 - val_loss: 1.7255 - val_acc: 0.3690
# Epoch 39/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6953 - acc: 0.3760 - val_loss: 1.7222 - val_acc: 0.3432
# Epoch 40/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6890 - acc: 0.3864 - val_loss: 1.7156 - val_acc: 0.3358
# Epoch 41/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6876 - acc: 0.3753 - val_loss: 1.7135 - val_acc: 0.3542
# Epoch 42/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.6853 - acc: 0.3688 - val_loss: 1.7138 - val_acc: 0.3653
# Epoch 43/200
# 48/48 [==============================] - 143s 3s/step - loss: 1.6891 - acc: 0.3792 - val_loss: 1.7098 - val_acc: 0.3838
# Epoch 44/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.6745 - acc: 0.4047 - val_loss: 1.7094 - val_acc: 0.3801
# Epoch 45/200
# 48/48 [==============================] - 7s 137ms/step - loss: 1.6745 - acc: 0.3877 - val_loss: 1.7055 - val_acc: 0.3690
# Epoch 46/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6807 - acc: 0.3740 - val_loss: 1.7031 - val_acc: 0.3911
# Epoch 47/200
# 48/48 [==============================] - 6s 118ms/step - loss: 1.6680 - acc: 0.3916 - val_loss: 1.6982 - val_acc: 0.3653
# Epoch 48/200
# 48/48 [==============================] - 26s 550ms/step - loss: 1.6695 - acc: 0.3825 - val_loss: 1.6989 - val_acc: 0.3875
# Epoch 49/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6654 - acc: 0.3910 - val_loss: 1.6948 - val_acc: 0.3985
# Epoch 50/200
# 48/48 [==============================] - 17s 370ms/step - loss: 1.6601 - acc: 0.3851 - val_loss: 1.6941 - val_acc: 0.3948
# Epoch 51/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6568 - acc: 0.4014 - val_loss: 1.6913 - val_acc: 0.3948
# Epoch 52/200
# 48/48 [==============================] - 91s 2s/step - loss: 1.6535 - acc: 0.4060 - val_loss: 1.6898 - val_acc: 0.4022
# Epoch 53/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.6598 - acc: 0.3936 - val_loss: 1.6825 - val_acc: 0.3875
# Epoch 54/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6536 - acc: 0.3949 - val_loss: 1.6808 - val_acc: 0.3985
# Epoch 55/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6516 - acc: 0.4040 - val_loss: 1.6812 - val_acc: 0.4096
# Epoch 56/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.6530 - acc: 0.4080 - val_loss: 1.6793 - val_acc: 0.4096
# Epoch 57/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6441 - acc: 0.4054 - val_loss: 1.6764 - val_acc: 0.3948
# Epoch 58/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6330 - acc: 0.4099 - val_loss: 1.6746 - val_acc: 0.4096
# Epoch 59/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6386 - acc: 0.4093 - val_loss: 1.6725 - val_acc: 0.4133
# Epoch 60/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6298 - acc: 0.4099 - val_loss: 1.6697 - val_acc: 0.4096
# Epoch 61/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6349 - acc: 0.4151 - val_loss: 1.6708 - val_acc: 0.4096
# Epoch 62/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6321 - acc: 0.4073 - val_loss: 1.6676 - val_acc: 0.4096
# Epoch 63/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6312 - acc: 0.4164 - val_loss: 1.6650 - val_acc: 0.4170
# Epoch 64/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6271 - acc: 0.4217 - val_loss: 1.6693 - val_acc: 0.4207
# Epoch 65/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6245 - acc: 0.4132 - val_loss: 1.6649 - val_acc: 0.4207
# Epoch 66/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.6241 - acc: 0.4145 - val_loss: 1.6604 - val_acc: 0.4207
# Epoch 67/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6167 - acc: 0.4164 - val_loss: 1.6632 - val_acc: 0.4244
# Epoch 68/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6139 - acc: 0.4230 - val_loss: 1.6602 - val_acc: 0.4170
# Epoch 69/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6186 - acc: 0.4282 - val_loss: 1.6557 - val_acc: 0.4170
# Epoch 70/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6071 - acc: 0.4289 - val_loss: 1.6566 - val_acc: 0.4170
# Epoch 71/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6093 - acc: 0.4184 - val_loss: 1.6546 - val_acc: 0.4244
# Epoch 72/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6136 - acc: 0.4230 - val_loss: 1.6538 - val_acc: 0.4244
# Epoch 73/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6056 - acc: 0.4334 - val_loss: 1.6511 - val_acc: 0.4244
# Epoch 74/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.6029 - acc: 0.4295 - val_loss: 1.6489 - val_acc: 0.4280
# Epoch 75/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5981 - acc: 0.4471 - val_loss: 1.6455 - val_acc: 0.4207
# Epoch 76/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5908 - acc: 0.4360 - val_loss: 1.6444 - val_acc: 0.4207
# Epoch 77/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5984 - acc: 0.4256 - val_loss: 1.6424 - val_acc: 0.4428
# Epoch 78/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5951 - acc: 0.4406 - val_loss: 1.6411 - val_acc: 0.4354
# Epoch 79/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5830 - acc: 0.4380 - val_loss: 1.6397 - val_acc: 0.4207
# Epoch 80/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5896 - acc: 0.4386 - val_loss: 1.6388 - val_acc: 0.4244
# Epoch 81/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5845 - acc: 0.4373 - val_loss: 1.6380 - val_acc: 0.4244
# Epoch 82/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5827 - acc: 0.4419 - val_loss: 1.6344 - val_acc: 0.4244
# Epoch 83/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5798 - acc: 0.4478 - val_loss: 1.6323 - val_acc: 0.4317
# Epoch 84/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5773 - acc: 0.4413 - val_loss: 1.6309 - val_acc: 0.4354
# Epoch 85/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5779 - acc: 0.4517 - val_loss: 1.6304 - val_acc: 0.4391
# Epoch 86/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5764 - acc: 0.4406 - val_loss: 1.6283 - val_acc: 0.4465
# Epoch 87/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5745 - acc: 0.4537 - val_loss: 1.6261 - val_acc: 0.4391
# Epoch 88/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5728 - acc: 0.4589 - val_loss: 1.6273 - val_acc: 0.4280
# Epoch 89/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5637 - acc: 0.4393 - val_loss: 1.6266 - val_acc: 0.4391
# Epoch 90/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5635 - acc: 0.4465 - val_loss: 1.6242 - val_acc: 0.4391
# Epoch 91/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5699 - acc: 0.4471 - val_loss: 1.6225 - val_acc: 0.4317
# Epoch 92/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5648 - acc: 0.4523 - val_loss: 1.6197 - val_acc: 0.4391
# Epoch 93/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5637 - acc: 0.4491 - val_loss: 1.6191 - val_acc: 0.4391
# Epoch 94/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5648 - acc: 0.4550 - val_loss: 1.6152 - val_acc: 0.4354
# Epoch 95/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5597 - acc: 0.4465 - val_loss: 1.6152 - val_acc: 0.4354
# Epoch 96/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5625 - acc: 0.4517 - val_loss: 1.6135 - val_acc: 0.4465
# Epoch 97/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5520 - acc: 0.4674 - val_loss: 1.6134 - val_acc: 0.4391
# Epoch 98/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5563 - acc: 0.4563 - val_loss: 1.6121 - val_acc: 0.4428
# Epoch 99/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5605 - acc: 0.4530 - val_loss: 1.6125 - val_acc: 0.4391
# Epoch 100/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5559 - acc: 0.4576 - val_loss: 1.6086 - val_acc: 0.4391
# Epoch 101/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5497 - acc: 0.4641 - val_loss: 1.6079 - val_acc: 0.4391
# Epoch 102/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5407 - acc: 0.4648 - val_loss: 1.6095 - val_acc: 0.4428
# Epoch 103/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5512 - acc: 0.4615 - val_loss: 1.6073 - val_acc: 0.4317
# Epoch 104/200
# 48/48 [==============================] - 65s 1s/step - loss: 1.5513 - acc: 0.4589 - val_loss: 1.6080 - val_acc: 0.4280
# Epoch 105/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.5448 - acc: 0.4608 - val_loss: 1.6032 - val_acc: 0.4391
# Epoch 106/200
# 48/48 [==============================] - 71s 2s/step - loss: 1.5437 - acc: 0.4595 - val_loss: 1.6021 - val_acc: 0.4391
# Epoch 107/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.5422 - acc: 0.4621 - val_loss: 1.6001 - val_acc: 0.4391
# Epoch 108/200
# 48/48 [==============================] - 120s 3s/step - loss: 1.5329 - acc: 0.4615 - val_loss: 1.5976 - val_acc: 0.4391
# Epoch 109/200
# 48/48 [==============================] - 172s 4s/step - loss: 1.5329 - acc: 0.4608 - val_loss: 1.5958 - val_acc: 0.4391
# Epoch 110/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5384 - acc: 0.4661 - val_loss: 1.5945 - val_acc: 0.4428
# Epoch 111/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5302 - acc: 0.4537 - val_loss: 1.5924 - val_acc: 0.4391
# Epoch 112/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.5294 - acc: 0.4680 - val_loss: 1.5916 - val_acc: 0.4428
# Epoch 113/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5258 - acc: 0.4739 - val_loss: 1.5914 - val_acc: 0.4465
# Epoch 114/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.5283 - acc: 0.4706 - val_loss: 1.5910 - val_acc: 0.4391
# Epoch 115/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.5273 - acc: 0.4713 - val_loss: 1.5891 - val_acc: 0.4354
# Epoch 116/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.5214 - acc: 0.4719 - val_loss: 1.5918 - val_acc: 0.4317
# Epoch 117/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5233 - acc: 0.4661 - val_loss: 1.5877 - val_acc: 0.4317
# Epoch 118/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5213 - acc: 0.4674 - val_loss: 1.5899 - val_acc: 0.4428
# Epoch 119/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5142 - acc: 0.4745 - val_loss: 1.5864 - val_acc: 0.4428
# Epoch 120/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5106 - acc: 0.4654 - val_loss: 1.5856 - val_acc: 0.4354
# Epoch 121/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5163 - acc: 0.4791 - val_loss: 1.5838 - val_acc: 0.4354
# Epoch 122/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5208 - acc: 0.4719 - val_loss: 1.5887 - val_acc: 0.4465
# Epoch 123/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5132 - acc: 0.4745 - val_loss: 1.5806 - val_acc: 0.4354
# Epoch 124/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5159 - acc: 0.4719 - val_loss: 1.5788 - val_acc: 0.4428
# Epoch 125/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5099 - acc: 0.4772 - val_loss: 1.5808 - val_acc: 0.4317
# Epoch 126/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5091 - acc: 0.4772 - val_loss: 1.5777 - val_acc: 0.4502
# Epoch 127/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5073 - acc: 0.4700 - val_loss: 1.5772 - val_acc: 0.4354
# Epoch 128/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4993 - acc: 0.4824 - val_loss: 1.5754 - val_acc: 0.4391
# Epoch 129/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5016 - acc: 0.4700 - val_loss: 1.5772 - val_acc: 0.4354
# Epoch 130/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4992 - acc: 0.4837 - val_loss: 1.5755 - val_acc: 0.4428
# Epoch 131/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.5056 - acc: 0.4732 - val_loss: 1.5741 - val_acc: 0.4391
# Epoch 132/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4974 - acc: 0.4856 - val_loss: 1.5705 - val_acc: 0.4354
# Epoch 133/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4914 - acc: 0.4804 - val_loss: 1.5672 - val_acc: 0.4428
# Epoch 134/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4857 - acc: 0.4850 - val_loss: 1.5700 - val_acc: 0.4317
# Epoch 135/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4972 - acc: 0.4863 - val_loss: 1.5690 - val_acc: 0.4428
# Epoch 136/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4949 - acc: 0.4856 - val_loss: 1.5675 - val_acc: 0.4317
# Epoch 137/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4877 - acc: 0.4785 - val_loss: 1.5671 - val_acc: 0.4428
# Epoch 138/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4925 - acc: 0.4843 - val_loss: 1.5666 - val_acc: 0.4391
# Epoch 139/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4913 - acc: 0.4876 - val_loss: 1.5660 - val_acc: 0.4502
# Epoch 140/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4905 - acc: 0.4850 - val_loss: 1.5647 - val_acc: 0.4354
# Epoch 141/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4838 - acc: 0.4902 - val_loss: 1.5620 - val_acc: 0.4391
# Epoch 142/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4835 - acc: 0.4811 - val_loss: 1.5625 - val_acc: 0.4317
# Epoch 143/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4835 - acc: 0.4843 - val_loss: 1.5621 - val_acc: 0.4428
# Epoch 144/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4777 - acc: 0.4824 - val_loss: 1.5590 - val_acc: 0.4428
# Epoch 145/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4825 - acc: 0.4804 - val_loss: 1.5615 - val_acc: 0.4428
# Epoch 146/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4744 - acc: 0.4902 - val_loss: 1.5570 - val_acc: 0.4391
# Epoch 147/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4757 - acc: 0.5000 - val_loss: 1.5563 - val_acc: 0.4502
# Epoch 148/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4719 - acc: 0.4909 - val_loss: 1.5546 - val_acc: 0.4502
# Epoch 149/200
# 48/48 [==============================] - 50s 1s/step - loss: 1.4736 - acc: 0.4843 - val_loss: 1.5570 - val_acc: 0.4391
# Epoch 150/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4812 - acc: 0.4922 - val_loss: 1.5550 - val_acc: 0.4502
# Epoch 151/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4699 - acc: 0.4863 - val_loss: 1.5544 - val_acc: 0.4317
# Epoch 152/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4701 - acc: 0.4889 - val_loss: 1.5528 - val_acc: 0.4465
# Epoch 153/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4683 - acc: 0.4902 - val_loss: 1.5515 - val_acc: 0.4391
# Epoch 154/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4570 - acc: 0.5013 - val_loss: 1.5494 - val_acc: 0.4465
# Epoch 155/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4604 - acc: 0.4909 - val_loss: 1.5502 - val_acc: 0.4391
# Epoch 156/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4580 - acc: 0.5000 - val_loss: 1.5477 - val_acc: 0.4354
# Epoch 157/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4621 - acc: 0.4902 - val_loss: 1.5483 - val_acc: 0.4317
# Epoch 158/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4626 - acc: 0.5000 - val_loss: 1.5489 - val_acc: 0.4465
# Epoch 159/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4580 - acc: 0.4974 - val_loss: 1.5445 - val_acc: 0.4391
# Epoch 160/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4549 - acc: 0.5078 - val_loss: 1.5441 - val_acc: 0.4391
# Epoch 161/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4536 - acc: 0.4974 - val_loss: 1.5475 - val_acc: 0.4465
# Epoch 162/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4560 - acc: 0.5013 - val_loss: 1.5456 - val_acc: 0.4465
# Epoch 163/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4515 - acc: 0.5026 - val_loss: 1.5441 - val_acc: 0.4391
# Epoch 164/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4470 - acc: 0.5085 - val_loss: 1.5424 - val_acc: 0.4354
# Epoch 165/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4489 - acc: 0.5000 - val_loss: 1.5386 - val_acc: 0.4465
# Epoch 166/200
# 48/48 [==============================] - 4s 92ms/step - loss: 1.4429 - acc: 0.4980 - val_loss: 1.5375 - val_acc: 0.4502
# Epoch 167/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4539 - acc: 0.5013 - val_loss: 1.5374 - val_acc: 0.4391
# Epoch 168/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4464 - acc: 0.5091 - val_loss: 1.5378 - val_acc: 0.4502
# Epoch 169/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4470 - acc: 0.5078 - val_loss: 1.5378 - val_acc: 0.4649
# Epoch 170/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4470 - acc: 0.5072 - val_loss: 1.5355 - val_acc: 0.4391
# Epoch 171/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4393 - acc: 0.5085 - val_loss: 1.5349 - val_acc: 0.4428
# Epoch 172/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4388 - acc: 0.5098 - val_loss: 1.5363 - val_acc: 0.4465
# Epoch 173/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4400 - acc: 0.4987 - val_loss: 1.5349 - val_acc: 0.4576
# Epoch 174/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4382 - acc: 0.5039 - val_loss: 1.5317 - val_acc: 0.4502
# Epoch 175/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4335 - acc: 0.5111 - val_loss: 1.5305 - val_acc: 0.4465
# Epoch 176/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4351 - acc: 0.5183 - val_loss: 1.5321 - val_acc: 0.4576
# Epoch 177/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4333 - acc: 0.5078 - val_loss: 1.5286 - val_acc: 0.4428
# Epoch 178/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4360 - acc: 0.5059 - val_loss: 1.5278 - val_acc: 0.4576
# Epoch 179/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4346 - acc: 0.5007 - val_loss: 1.5305 - val_acc: 0.4613
# Epoch 180/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4373 - acc: 0.5039 - val_loss: 1.5270 - val_acc: 0.4502
# Epoch 181/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4301 - acc: 0.5091 - val_loss: 1.5270 - val_acc: 0.4613
# Epoch 182/200
# 48/48 [==============================] - 4s 90ms/step - loss: 1.4345 - acc: 0.5098 - val_loss: 1.5261 - val_acc: 0.4613
# Epoch 183/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4289 - acc: 0.5078 - val_loss: 1.5262 - val_acc: 0.4539
# Epoch 184/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4202 - acc: 0.5137 - val_loss: 1.5265 - val_acc: 0.4576
# Epoch 185/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.4302 - acc: 0.5059 - val_loss: 1.5228 - val_acc: 0.4539
# Epoch 186/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4211 - acc: 0.5085 - val_loss: 1.5209 - val_acc: 0.4539
# Epoch 187/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4223 - acc: 0.5059 - val_loss: 1.5204 - val_acc: 0.4502
# Epoch 188/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4184 - acc: 0.5144 - val_loss: 1.5181 - val_acc: 0.4613
# Epoch 189/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4254 - acc: 0.5033 - val_loss: 1.5220 - val_acc: 0.4613
# Epoch 190/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4133 - acc: 0.5235 - val_loss: 1.5197 - val_acc: 0.4539
# Epoch 191/200
# 48/48 [==============================] - 4s 88ms/step - loss: 1.4152 - acc: 0.5183 - val_loss: 1.5192 - val_acc: 0.4613
# Epoch 192/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4156 - acc: 0.5091 - val_loss: 1.5188 - val_acc: 0.4576
# Epoch 193/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4143 - acc: 0.5222 - val_loss: 1.5153 - val_acc: 0.4465
# Epoch 194/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4145 - acc: 0.5163 - val_loss: 1.5155 - val_acc: 0.4649
# Epoch 195/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4083 - acc: 0.5222 - val_loss: 1.5172 - val_acc: 0.4686
# Epoch 196/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4062 - acc: 0.5176 - val_loss: 1.5154 - val_acc: 0.4539
# Epoch 197/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4066 - acc: 0.5144 - val_loss: 1.5171 - val_acc: 0.4686
# Epoch 198/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.3974 - acc: 0.5346 - val_loss: 1.5123 - val_acc: 0.4428
# Epoch 199/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4061 - acc: 0.5248 - val_loss: 1.5107 - val_acc: 0.4613
# Epoch 200/200
# 48/48 [==============================] - 4s 89ms/step - loss: 1.4065 - acc: 0.5176 - val_loss: 1.5152 - val_acc: 0.4723

# %%
plt.figure(1,figsize=(10,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Train Loss vs Validation Loss')
plt.grid(True)
plt.legend(['Train Loss','Validation Loss'])
plt.style.use('classic')

# %%
plt.figure(2,figsize=(10,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.title('Train Accuracy vs Validation Accuracy')
plt.grid(True)
plt.legend(['Train Accuracy','Validation Accuracy'],loc=4)

# %%
score = cnn_model.evaluate(X_test, y_test, verbose=0)
print('Test Loss:', score[0])
print('Test Accuracy:', score[1])
# Out:
# Test Loss: 1.515159010887146
# Test Accuracy: 0.4723247289657593

# %%
test_image = X_test[0:1]
# print (test_image.shape)
print(cnn_model.predict(test_image))
prediction = cnn_model.predict(test_image)
print(y_test[0:1])

image = test_image.reshape((128,128))
plt.imshow(image)
plt.show()
# Out:
# [[0.1819286  0.15096831 0.19342422 0.1733741  0.10198843 0.1251774
#   0.07313892]]
# [[0. 0. 0. 1. 0. 0. 0.]]

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = cnn_model.predict(X_test)
print(Y_pred)
y_pred = np.argmax(Y_pred,axis=1)
print(y_pred)
print(class_dict)
print(classification_report(np.argmax(y_test,axis=1),y_pred,target_names=class_dict))
# Out:
# [[0.18192871 0.15096854 0.19342442 ... 0.10198857 0.12517695 0.07313918]
#  [0.09737223 0.07039259 0.32229105 ... 0.10930359 0.07874686 0.10571183]
#  [0.07071325 0.05932612 0.13069746 ... 0.10895452 0.5593435  0.04957252]
#  ...
#  [0.16507258 0.09694591 0.1300945  ... 0.2352365  0.29197067 0.071964  ]
#  [0.06158293 0.06528611 0.10919932 ... 0.05723784 0.64889276 0.05013816]
#  [0.11206748 0.10537715 0.23975973 ... 0.20918904 0.17905854 0.1331255 ]]
# [2 2 5 2 4 2 2 6 2 5 4 5 2 2 4 4 5 6 5 5 3 6 6 2 4 5 5 5 4 5 5 5 5 4 3 5 5
#  4 5 3 3 4 6 6 3 5 4 2 2 5 3 3 6 2 2 5 5 5 5 4 6 5 3 4 3 2 5 2 6 6 5 2 6 4
#  5 5 5 2 5 2 2 5 5 5 4 5 5 2 3 2 2 2 2 4 6 3 3 2 3 2 5 2 2 4 5 3 6 2 4 2 6
#  4 6 4 2 2 3 2 2 3 3 5 3 5 2 3 3 4 6 2 2 5 5 4 4 5 3 6 2 5 2 5 2 3 2 5 5 3
#  2 5 0 5 2 5 5 5 4 2 5 5 5 4 5 2 5 5 5 5 3 5 5 4 5 3 6 4 2 2 5 6 2 2 4 3 2
#  2 5 4 5 5 2 5 2 5 5 3 3 5 5 2 2 5 5 5 6 3 2 5 2 3 5 3 5 5 6 3 5 6 3 4 5 5
#  1 4 2 2 2 3 6 5 5 3 4 2 2 2 5 6 3 5 3 5 5 2 5 4 5 4 2 2 3 3 6 2 2 5 2 5 3
#  5 5 5 0 6 2 4 0 2 5 5 2]
# {'dogs': 0, 'cats': 1, 'bike': 2, 'flowers': 3, 'horses': 4, 'cars': 5, 'human': 6}
#               precision    recall  f1-score   support
#
#         dogs       0.00      0.00      0.00        27
#         cats       0.00      0.00      0.00        34
#         bike       0.54      0.70      0.61        56
#      flowers       0.50      0.65      0.56        31
#       horses       0.41      0.52      0.46        27
#         cars       0.42      0.63      0.51        63
#        human       0.58      0.45      0.51        33
#
#     accuracy                           0.47       271
#    macro avg       0.35      0.42      0.38       271
# weighted avg       0.38      0.47      0.42       271
